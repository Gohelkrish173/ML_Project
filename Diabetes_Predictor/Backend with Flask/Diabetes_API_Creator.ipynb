# %%
#conda install -c conda-forge flask-cors

# %%
from flask import Flask, request, jsonify
import pandas as pd
import numpy as np
import joblib
from flask_cors import CORS

# %%
app = Flask(__name__)
CORS(app, resources={r"/predict": {"origins": "http://localhost:4200"}})

# %%
model = joblib.load("svc_rbf_model.pkl")
scaler = joblib.load("std_scaler.pkl")

# %%
@app.route("/predict", methods=["POST"])
def predict():
    data = request.json
    features = np.array(data["features"]).reshape(1, -1)  # Convert input to NumPy array

    # Standardize input using the same scaler
    features_scaled = scaler.transform(features)

    # Make prediction
    prediction = model.predict(features_scaled)
    
    return jsonify({"prediction": prediction.tolist()})

if __name__ == '__main__':
    app.run(debug=True,use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 08:34:51] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:36:22] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:42:32] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:45:33] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:47:43] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 08:47:43] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:47:55] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:48:33] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:49:23] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:51:03] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 08:51:24] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:53:13] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 08:53:14] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:55:02] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:55:46] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:56:08] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:56:18] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:56:36] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:57:22] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 08:57:22] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:57:30] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 08:57:30] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 08:58:46] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 08:58:46] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 09:02:39] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 09:03:34] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 09:03:34] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2548, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\AppData\Local\Temp\ipykernel_20752\108495608.py", line 7, in predict
#     features_scaled = scaler.transform(features)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py", line 1004, in transform
#     X = self._validate_data(
#         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 917, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: ''
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 09:03:35] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2548, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\AppData\Local\Temp\ipykernel_20752\108495608.py", line 7, in predict
#     features_scaled = scaler.transform(features)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py", line 1004, in transform
#     X = self._validate_data(
#         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 917, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: ''
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 09:03:36] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2548, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask_cors\extension.py", line 176, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\AppData\Local\Temp\ipykernel_20752\108495608.py", line 7, in predict
#     features_scaled = scaler.transform(features)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py", line 1004, in transform
#     X = self._validate_data(
#         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 917, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: ''
# 127.0.0.1 - - [11/Mar/2025 09:04:01] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 09:04:01] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 09:06:52] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 09:06:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 09:07:01] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 09:07:01] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Mar/2025 09:08:16] "OPTIONS /predict HTTP/1.1" 200 -
# C:\Users\Krish\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [11/Mar/2025 09:08:16] "POST /predict HTTP/1.1" 200 -
